# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'QKHGQ4BJMPYGBPOLQ0GOF2FAGFNGYMISRS4ELCM4ITYWQSJO' # your Foursquare ID
CLIENT_SECRET = '44QQXDSPM2IKXWMXQ5PGUK3D1ICKTFXGZQH2X4RSYDUHMFQO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QKHGQ4BJMPYGBPOLQ0GOF2FAGFNGYMISRS4ELCM4ITYWQSJO
# CLIENT_SECRET:44QQXDSPM2IKXWMXQ5PGUK3D1ICKTFXGZQH2X4RSYDUHMFQO

# %%
address = 'London'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.5073219 -0.1276474

# %%
search_query = 'sustainable','ethical'
radius = 10000
print(search_query)
# Out:
# ('sustainable', 'ethical')

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# "https://api.foursquare.com/v2/venues/search?client_id=QKHGQ4BJMPYGBPOLQ0GOF2FAGFNGYMISRS4ELCM4ITYWQSJO&client_secret=44QQXDSPM2IKXWMXQ5PGUK3D1ICKTFXGZQH2X4RSYDUHMFQO&ll=51.5073219,-0.1276474&v=20180604&query=('sustainable', 'ethical')&radius=10000&limit=30"

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ef30d4683d66d0312ae12d1'},
#  'response': {'venues': [{'id': '5caf67d67564f700394343b5',
#     'name': 'Sustainable Workspaces',
#     'location': {'lat': 51.506659,
#      'lng': -0.097457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.506659,
#        'lng': -0.097457}],
#      'distance': 2093,
#      'postalCode': 'SE1 9DY',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'SE1 9DY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '5557cb2a498e47aaf26b344b',
#     'name': 'Sustainable Bridges',
#     'location': {'address': '29 Shand Street',
#      'lat': 51.50286581276557,
#      'lng': -0.08126020431518555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50286581276557,
#        'lng': -0.08126020431518555}],
#      'distance': 3252,
#      'postalCode': 'SE1 2ES',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['29 Shand Street',
#       'London',
#       'Greater London',
#       'SE1 2ES',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '57756efd498e5a7c0cdc9154',
#     'name': 'Sustainable Prospects',
#     'location': {'address': '20-22 Wenlock Road',
#      'lat': 51.5305724,
#      'lng': -0.0934913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5305724,
#        'lng': -0.0934913}],
#      'distance': 3506,
#      'postalCode': 'N1 7GU',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['20-22 Wenlock Road',
#       'London',
#       'Greater London',
#       'N1 7GU',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '56cc6edccd107ba4806d05bc',
#     'name': 'Sustainable Empowerment',
#     'location': {'address': '5, Blades Court, 16 Lower Mall, Hammersmith',
#      'lat': 51.4897651,
#      'lng': -0.2316228,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4897651,
#        'lng': -0.2316228}],
#      'distance': 7465,
#      'postalCode': 'W6 9DJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5, Blades Court, 16 Lower Mall, Hammersmith',
#       'London',
#       'Greater London',
#       'W6 9DJ',
#       'United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a39',
#       'name': 'Mental Health Office',
#       'pluralName': 'Mental Health Offices',
#       'shortName': 'Mental Health',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '54295c3b498ed8ce5def0d85',
#     'name': 'SDCL - Sustainable Development Capital LLP',
#     'location': {'address': '32 Old Burlington Street',
#      'lat': 51.51048105985578,
#      'lng': -0.14054486729602306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51048105985578,
#        'lng': -0.14054486729602306}],
#      'distance': 960,
#      'postalCode': 'W1S 3AT',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['32 Old Burlington Street',
#       'London',
#       'Greater London',
#       'W1S 3AT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '4f8d8f91e4b05426ef8319c2',
#     'name': 'The Grayston Centre | Ethical Property',
#     'location': {'address': '28 Charles Square, Old Street',
#      'lat': 51.52746530216066,
#      'lng': -0.0842979734400269,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52746530216066,
#        'lng': -0.0842979734400269}],
#      'distance': 3747,
#      'postalCode': 'N1 6HT',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['28 Charles Square, Old Street',
#       'London',
#       'Greater London',
#       'N1 6HT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '578623894'},
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '4c7e9bc0a7958cfa77458e2b',
#     'name': 'South Place Ethical Society',
#     'location': {'address': 'Red Lion Square',
#      'lat': 51.52042739183921,
#      'lng': -0.10847148944550325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52042739183921,
#        'lng': -0.10847148944550325}],
#      'distance': 1973,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Red Lion Square',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1af941735',
#       'name': 'College Auditorium',
#       'pluralName': 'College Auditoriums',
#       'shortName': 'Auditorium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '564b0e2f498e154bc6441a61',
#     'name': 'Ingle & Rhode - The Ethical Jeweller',
#     'location': {'address': "14 Gee's Ct",
#      'lat': 51.51450238,
#      'lng': -0.15013556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51450238,
#        'lng': -0.15013556}],
#      'distance': 1751,
#      'postalCode': 'W1U 1JW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["14 Gee's Ct",
#       'London',
#       'Greater London',
#       'W1U 1JW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '148304610'},
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '5b6c328e1ffe97003924eeca',
#     'name': 'The Green House | Ethical Property',
#     'location': {'address': '244-254 Cambridge Heath Road',
#      'lat': 51.532778,
#      'lng': -0.057003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.532778,
#        'lng': -0.057003}],
#      'distance': 5654,
#      'postalCode': 'E2 9DA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['244-254 Cambridge Heath Road',
#       'London',
#       'Greater London',
#       'E2 9DA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '580367741'},
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '51824d94498ee2fcc719094e',
#     'name': 'Centre For Sustainable Fashion',
#     'location': {'address': 'London College Of Fashion',
#      'crossStreet': '20 John Princess Street',
#      'lat': 51.515399,
#      'lng': -0.144551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.515399,
#        'lng': -0.144551}],
#      'distance': 1476,
#      'postalCode': 'W1G 0BJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London College Of Fashion (20 John Princess Street)',
#       'London',
#       'Greater London',
#       'W1G 0BJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '4e7337db62e1a77aacb1c39c',
#     'name': 'Ethical Trading Initiative',
#     'location': {'address': '8 bath square',
#      'lat': 51.5248255847311,
#      'lng': -0.14344439935864295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5248255847311,
#        'lng': -0.14344439935864295}],
#      'distance': 2234,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['8 bath square',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '5b883ad31b0ea500392a0225',
#     'name': 'Ethical Caffeine',
#     'location': {'lat': 51.504242,
#      'lng': -0.095608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.504242,
#        'lng': -0.095608}],
#      'distance': 2246,
#      'postalCode': 'SE1',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'SE1',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '4d30306f10e9b1f7cf60b8f1',
#     'name': 'Sustainable Restaurant Association',
#     'location': {'address': '25 Gerrard St',
#      'lat': 51.419067655510744,
#      'lng': -0.20250702337020984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.419067655510744,
#        'lng': -0.20250702337020984}],
#      'distance': 11111,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['25 Gerrard St',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '4f63609a1081a8f3d5e7d86d',
#     'name': 'Ethical Fashion Forum',
#     'location': {'address': 'Rich Mix, Unit C02',
#      'crossStreet': '35-47 Bethnal Green Rd.',
#      'lat': 51.5241611838997,
#      'lng': -0.07326944104525683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5241611838997,
#        'lng': -0.07326944104525683}],
#      'distance': 4207,
#      'postalCode': 'E1 6LA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Rich Mix, Unit C02 (35-47 Bethnal Green Rd.)',
#       'London',
#       'Greater London',
#       'E1 6LA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False},
#    {'id': '5d57e47be7a6680007d16c70',
#     'name': 'Ethical Bean Company',
#     'location': {'address': '41 Dace Road',
#      'lat': 51.537754,
#      'lng': -0.024061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.537754,
#        'lng': -0.024061}],
#      'distance': 7934,
#      'postalCode': 'E3 2NG',
#      'cc': 'GB',
#      'neighborhood': 'Tower Hamlets',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['41 Dace Road',
#       'London',
#       'Greater London',
#       'E3 2NG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592987536',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                          id                                        name  \
# 0  5caf67d67564f700394343b5                      Sustainable Workspaces
# 1  5557cb2a498e47aaf26b344b                         Sustainable Bridges
# 2  57756efd498e5a7c0cdc9154                       Sustainable Prospects
# 3  56cc6edccd107ba4806d05bc                     Sustainable Empowerment
# 4  54295c3b498ed8ce5def0d85  SDCL - Sustainable Development Capital LLP
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...  v-1592987536    False
# 1  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...  v-1592987536    False
# 2                                                 []  v-1592987536    False
# 3  [{'id': '52e81612bcbc57f1066b7a39', 'name': 'M...  v-1592987536    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1592987536    False
#
#    location.lat  location.lng  \
# 0     51.506659     -0.097457
# 1     51.502866     -0.081260
# 2     51.530572     -0.093491
# 3     51.489765     -0.231623
# 4     51.510481     -0.140545
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.506659, 'lng':...               2093
# 1  [{'label': 'display', 'lat': 51.50286581276557...               3252
# 2  [{'label': 'display', 'lat': 51.5305724, 'lng'...               3506
# 3  [{'label': 'display', 'lat': 51.4897651, 'lng'...               7465
# 4  [{'label': 'display', 'lat': 51.51048105985578...                960
#
#   location.postalCode location.cc location.city  location.state  \
# 0             SE1 9DY          GB        London  Greater London
# 1             SE1 2ES          GB        London  Greater London
# 2              N1 7GU          GB        London  Greater London
# 3              W6 9DJ          GB        London  Greater London
# 4             W1S 3AT          GB        London  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [London, Greater London, SE1 9DY, United Kingdom]
# 1   United Kingdom  [29 Shand Street, London, Greater London, SE1 ...
# 2   United Kingdom  [20-22 Wenlock Road, London, Greater London, N...
# 3   United Kingdom  [5, Blades Court, 16 Lower Mall, Hammersmith, ...
# 4   United Kingdom  [32 Old Burlington Street, London, Greater Lon...
#
#                               location.address venuePage.id  \
# 0                                          NaN          NaN
# 1                              29 Shand Street          NaN
# 2                           20-22 Wenlock Road          NaN
# 3  5, Blades Court, 16 Lower Mall, Hammersmith          NaN
# 4                     32 Old Burlington Street          NaN
#
#   location.crossStreet location.neighborhood
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                           name            categories  \
# 0                       Sustainable Workspaces       Coworking Space
# 1                          Sustainable Bridges       Coworking Space
# 2                        Sustainable Prospects                  None
# 3                      Sustainable Empowerment  Mental Health Office
# 4   SDCL - Sustainable Development Capital LLP                Office
# 5       The Grayston Centre | Ethical Property       Coworking Space
# 6                  South Place Ethical Society    College Auditorium
# 7         Ingle & Rhode - The Ethical Jeweller         Jewelry Store
# 8           The Green House | Ethical Property                Office
# 9               Centre For Sustainable Fashion                Office
# 10                  Ethical Trading Initiative                Office
# 11                            Ethical Caffeine           Coffee Shop
# 12          Sustainable Restaurant Association                  None
# 13                       Ethical Fashion Forum       Coworking Space
# 14                        Ethical Bean Company           Coffee Shop
#
#           lat       lng                                     labeledLatLngs  \
# 0   51.506659 -0.097457  [{'label': 'display', 'lat': 51.506659, 'lng':...
# 1   51.502866 -0.081260  [{'label': 'display', 'lat': 51.50286581276557...
# 2   51.530572 -0.093491  [{'label': 'display', 'lat': 51.5305724, 'lng'...
# 3   51.489765 -0.231623  [{'label': 'display', 'lat': 51.4897651, 'lng'...
# 4   51.510481 -0.140545  [{'label': 'display', 'lat': 51.51048105985578...
# 5   51.527465 -0.084298  [{'label': 'display', 'lat': 51.52746530216066...
# 6   51.520427 -0.108471  [{'label': 'display', 'lat': 51.52042739183921...
# 7   51.514502 -0.150136  [{'label': 'display', 'lat': 51.51450238, 'lng...
# 8   51.532778 -0.057003  [{'label': 'display', 'lat': 51.532778, 'lng':...
# 9   51.515399 -0.144551  [{'label': 'display', 'lat': 51.515399, 'lng':...
# 10  51.524826 -0.143444  [{'label': 'display', 'lat': 51.5248255847311,...
# 11  51.504242 -0.095608  [{'label': 'display', 'lat': 51.504242, 'lng':...
# 12  51.419068 -0.202507  [{'label': 'display', 'lat': 51.41906765551074...
# 13  51.524161 -0.073269  [{'label': 'display', 'lat': 51.5241611838997,...
# 14  51.537754 -0.024061  [{'label': 'display', 'lat': 51.537754, 'lng':...
#
#     distance postalCode  cc    city           state         country  \
# 0       2093    SE1 9DY  GB  London  Greater London  United Kingdom
# 1       3252    SE1 2ES  GB  London  Greater London  United Kingdom
# 2       3506     N1 7GU  GB  London  Greater London  United Kingdom
# 3       7465     W6 9DJ  GB  London  Greater London  United Kingdom
# 4        960    W1S 3AT  GB  London  Greater London  United Kingdom
# 5       3747     N1 6HT  GB  London  Greater London  United Kingdom
# 6       1973        NaN  GB  London  Greater London  United Kingdom
# 7       1751    W1U 1JW  GB  London  Greater London  United Kingdom
# 8       5654     E2 9DA  GB  London  Greater London  United Kingdom
# 9       1476    W1G 0BJ  GB  London  Greater London  United Kingdom
# 10      2234        NaN  GB  London  Greater London  United Kingdom
# 11      2246        SE1  GB  London  Greater London  United Kingdom
# 12     11111        NaN  GB  London  Greater London  United Kingdom
# 13      4207     E1 6LA  GB  London  Greater London  United Kingdom
# 14      7934     E3 2NG  GB  London  Greater London  United Kingdom
#
#                                      formattedAddress  \
# 0   [London, Greater London, SE1 9DY, United Kingdom]
# 1   [29 Shand Street, London, Greater London, SE1 ...
# 2   [20-22 Wenlock Road, London, Greater London, N...
# 3   [5, Blades Court, 16 Lower Mall, Hammersmith, ...
# 4   [32 Old Burlington Street, London, Greater Lon...
# 5   [28 Charles Square, Old Street, London, Greate...
# 6   [Red Lion Square, London, Greater London, Unit...
# 7   [14 Gee's Ct, London, Greater London, W1U 1JW,...
# 8   [244-254 Cambridge Heath Road, London, Greater...
# 9   [London College Of Fashion (20 John Princess S...
# 10  [8 bath square, London, Greater London, United...
# 11      [London, Greater London, SE1, United Kingdom]
# 12  [25 Gerrard St, London, Greater London, United...
# 13  [Rich Mix, Unit C02 (35-47 Bethnal Green Rd.),...
# 14  [41 Dace Road, London, Greater London, E3 2NG,...
#
#                                         address              crossStreet  \
# 0                                           NaN                      NaN
# 1                               29 Shand Street                      NaN
# 2                            20-22 Wenlock Road                      NaN
# 3   5, Blades Court, 16 Lower Mall, Hammersmith                      NaN
# 4                      32 Old Burlington Street                      NaN
# 5                 28 Charles Square, Old Street                      NaN
# 6                               Red Lion Square                      NaN
# 7                                   14 Gee's Ct                      NaN
# 8                  244-254 Cambridge Heath Road                      NaN
# 9                     London College Of Fashion  20 John Princess Street
# 10                                8 bath square                      NaN
# 11                                          NaN                      NaN
# 12                                25 Gerrard St                      NaN
# 13                           Rich Mix, Unit C02  35-47 Bethnal Green Rd.
# 14                                 41 Dace Road                      NaN
#
#      neighborhood                        id
# 0             NaN  5caf67d67564f700394343b5
# 1             NaN  5557cb2a498e47aaf26b344b
# 2             NaN  57756efd498e5a7c0cdc9154
# 3             NaN  56cc6edccd107ba4806d05bc
# 4             NaN  54295c3b498ed8ce5def0d85
# 5             NaN  4f8d8f91e4b05426ef8319c2
# 6             NaN  4c7e9bc0a7958cfa77458e2b
# 7             NaN  564b0e2f498e154bc6441a61
# 8             NaN  5b6c328e1ffe97003924eeca
# 9             NaN  51824d94498ee2fcc719094e
# 10            NaN  4e7337db62e1a77aacb1c39c
# 11            NaN  5b883ad31b0ea500392a0225
# 12            NaN  4d30306f10e9b1f7cf60b8f1
# 13            NaN  4f63609a1081a8f3d5e7d86d
# 14  Tower Hamlets  5d57e47be7a6680007d16c70

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=12)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=10,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
